# %% [markdown]
# # EDA (Statistics)

# %%
import numpy as np
import pandas as pd
import gdown
import os

# %%
output = 'eeg_data2.csv'
if not os.path.exists(output):
    gdown.download('https://drive.google.com/file/d/1-UyzhlU74sLsrxa6niwPuUlH0F13J8Lq/view?usp=sharing', output, fuzzy=True)

# %%
eeg_df = pd.read_csv(output)

# %%
eeg_df.head()
# Out:
#    Unnamed: 0 participant_id  Original_ID sex  age            GROUP  BDI  \
# 0           0        sub-001        10600   F   43              CTL   14
# 1           1        sub-002        10601   F   50              CTL    2
# 2           2        sub-003        10602   F   22              CTL    2
# 3           5        sub-006        10605   F   24              CTL    8
# 4           6        sub-007        10606   M   44  ALC_early_state    5
#
#    AUDIT  EDUCATION       fp1  ...        c2       fc4       ft8        f6  \
# 0      1         16 -0.006885  ... -0.006757 -0.000072 -0.013844 -0.011792
# 1      2         16  0.006728  ... -0.009466 -0.003701  0.011509  0.003604
# 2      1         18 -0.026259  ... -0.001402 -0.009827 -0.016021 -0.013534
# 3      3         19 -0.005962  ...  0.013867 -0.003909  0.000481 -0.009388
# 4      7         16 -0.010039  ...  0.009685  0.008228  0.011959  0.005457
#
#          f2       af4       af8     empty       ekg  audiooutput
# 0 -0.009998 -0.012524 -0.025626  0.012368  1.830811     0.002748
# 1  0.009692 -0.008439  0.004798  2.803576  0.004948     0.002710
# 2  0.005141  0.000050 -0.023162  0.012644  1.379198     0.002720
# 3 -0.007416  0.000051 -0.006602  0.012423 -0.186586     0.002769
# 4  0.002437  0.007888  0.001032  0.012321  0.379675     1.040810
#
# [5 rows x 75 columns]

# %%
eeg_df.describe()
# Out:
#        Unnamed: 0   Original_ID        age        BDI      AUDIT  EDUCATION  \
# count   48.000000     48.000000  48.000000  48.000000  48.000000  48.000000
# mean    27.875000  10629.729167  38.437500   7.770833   6.125000  15.770833
# std     15.887403     17.196907   9.754227  10.794482   6.360199   2.722949
# min      0.000000  10600.000000  22.000000   0.000000   0.000000  10.000000
# 25%     13.750000  10613.750000  30.750000   1.000000   1.000000  13.750000
# 50%     29.500000  10631.500000  39.000000   4.000000   4.000000  16.000000
# 75%     41.250000  10644.250000  45.500000   8.000000  10.000000  17.250000
# max     53.000000  10658.000000  55.000000  42.000000  27.000000  23.000000
#
#              fp1         fz         f3         f7  ...         c2        fc4  \
# count  48.000000  48.000000  48.000000  48.000000  ...  48.000000  48.000000
# mean   -0.009657  -0.000706  -0.002677  -0.005779  ...   0.000797  -0.003902
# std     0.012262   0.011235   0.010066   0.015877  ...   0.009840   0.010472
# min    -0.033660  -0.022063  -0.024324  -0.036846  ...  -0.030557  -0.025966
# 25%    -0.020506  -0.006197  -0.008283  -0.017823  ...  -0.005442  -0.009546
# 50%    -0.008110   0.000234  -0.003742  -0.005798  ...   0.000418  -0.003805
# 75%    -0.003707   0.001976   0.003171   0.006861  ...   0.007006   0.003727
# max     0.020870   0.025463   0.026183   0.028762  ...   0.028374   0.021531
#
#              ft8         f6         f2        af4        af8      empty  \
# count  48.000000  48.000000  48.000000  48.000000  48.000000  48.000000
# mean   -0.007351  -0.003459  -0.000247  -0.003679  -0.010356   0.070583
# std     0.012606   0.011737   0.010699   0.012399   0.012371   0.402867
# min    -0.036140  -0.029962  -0.025524  -0.032982  -0.035959   0.012151
# 25%    -0.015913  -0.011821  -0.005766  -0.008519  -0.019959   0.012363
# 50%    -0.008789  -0.002809   0.000901  -0.002907  -0.011516   0.012426
# 75%     0.002130   0.004045   0.005789   0.001978  -0.003470   0.012518
# max     0.016033   0.023527   0.024353   0.029482   0.015446   2.803576
#
#              ekg  audiooutput
# count  48.000000    48.000000
# mean   -0.016613     0.026787
# std     0.874360     0.150553
# min    -2.475861     0.002360
# 25%    -0.330741     0.002394
# 50%     0.032979     0.002417
# 75%     0.281933     0.002796
# max     1.830811     1.040810
#
# [8 rows x 72 columns]

# %%
eeg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 75 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      48 non-null     int64
#  1   participant_id  48 non-null     object
#  2   Original_ID     48 non-null     int64
#  3   sex             48 non-null     object
#  4   age             48 non-null     int64
#  5   GROUP           48 non-null     object
#  6   BDI             48 non-null     int64
#  7   AUDIT           48 non-null     int64
#  8   EDUCATION       48 non-null     int64
#  9   fp1             48 non-null     float64
#  10  fz              48 non-null     float64
#  11  f3              48 non-null     float64
#  12  f7              48 non-null     float64
#  13  below_eye       48 non-null     float64
#  14  fc5             48 non-null     float64
#  15  fc1             48 non-null     float64
#  16  c3              48 non-null     float64
#  17  t7              48 non-null     float64
#  18  left_mastoid    48 non-null     float64
#  19  cp5             48 non-null     float64
#  20  cp1             48 non-null     float64
#  21  pz              48 non-null     float64
#  22  p3              48 non-null     float64
#  23  p7              48 non-null     float64
#  24  o1              48 non-null     float64
#  25  oz              48 non-null     float64
#  26  o2              48 non-null     float64
#  27  p4              48 non-null     float64
#  28  p8              48 non-null     float64
#  29  right_mastoid   48 non-null     float64
#  30  cp6             48 non-null     float64
#  31  cp2             48 non-null     float64
#  32  cz              48 non-null     float64
#  33  c4              48 non-null     float64
#  34  t8              48 non-null     float64
#  35  above_eye       48 non-null     float64
#  36  fc6             48 non-null     float64
#  37  fc2             48 non-null     float64
#  38  f4              48 non-null     float64
#  39  f8              48 non-null     float64
#  40  fp2             48 non-null     float64
#  41  af7             48 non-null     float64
#  42  af3             48 non-null     float64
#  43  afz             48 non-null     float64
#  44  f1              48 non-null     float64
#  45  f5              48 non-null     float64
#  46  ft7             48 non-null     float64
#  47  fc3             48 non-null     float64
#  48  fcz             48 non-null     float64
#  49  c1              48 non-null     float64
#  50  c5              48 non-null     float64
#  51  tp7             48 non-null     float64
#  52  cp3             48 non-null     float64
#  53  p1              48 non-null     float64
#  54  p5              48 non-null     float64
#  55  po7             48 non-null     float64
#  56  po3             48 non-null     float64
#  57  poz             48 non-null     float64
#  58  po4             48 non-null     float64
#  59  po8             48 non-null     float64
#  60  p6              48 non-null     float64
#  61  p2              48 non-null     float64
#  62  cp4             48 non-null     float64
#  63  tp8             48 non-null     float64
#  64  c6              48 non-null     float64
#  65  c2              48 non-null     float64
#  66  fc4             48 non-null     float64
#  67  ft8             48 non-null     float64
#  68  f6              48 non-null     float64
#  69  f2              48 non-null     float64
#  70  af4             48 non-null     float64
#  71  af8             48 non-null     float64
#  72  empty           48 non-null     float64
#  73  ekg             48 non-null     float64
#  74  audiooutput     48 non-null     float64
# dtypes: float64(66), int64(6), object(3)
# memory usage: 28.2+ KB

# %%
'''
    Find Columns with missing values
'''

missing_columns = eeg_df.columns[eeg_df.isna().any()]
missing_columns
# Out:
# Index([], dtype='object')

# %%
# eeg_df[missing_columns].head()

# %%
# eeg_df[missing_columns].describe()

# %%
# for column in missing_columns:
#     eeg_df[column] = eeg_df[column].fillna(value=eeg_df[column].mean())

# %% [markdown]
# ### After fill missing value with means

# %%
'''
    After Fill missing values with mean of each columns
'''

# eeg_df.head()
# Out:
# '\n    After Fill missing values with mean of each columns\n'

# %%
# eeg_df[missing_columns].head()

# %%
# eeg_df[missing_columns].describe()

# %%
eeg_df.columns
# Out:
# Index(['Unnamed: 0', 'participant_id', 'Original_ID', 'sex', 'age', 'GROUP',
#        'BDI', 'AUDIT', 'EDUCATION', 'fp1', 'fz', 'f3', 'f7', 'below_eye',
#        'fc5', 'fc1', 'c3', 't7', 'left_mastoid', 'cp5', 'cp1', 'pz', 'p3',
#        'p7', 'o1', 'oz', 'o2', 'p4', 'p8', 'right_mastoid', 'cp6', 'cp2', 'cz',
#        'c4', 't8', 'above_eye', 'fc6', 'fc2', 'f4', 'f8', 'fp2', 'af7', 'af3',
#        'afz', 'f1', 'f5', 'ft7', 'fc3', 'fcz', 'c1', 'c5', 'tp7', 'cp3', 'p1',
#        'p5', 'po7', 'po3', 'poz', 'po4', 'po8', 'p6', 'p2', 'cp4', 'tp8', 'c6',
#        'c2', 'fc4', 'ft8', 'f6', 'f2', 'af4', 'af8', 'empty', 'ekg',
#        'audiooutput'],
#       dtype='object')

# %% [markdown]
# ### Drop Unnecessary columns

# %%
eeg_df2 = eeg_df.drop(columns=['participant_id', 'Original_ID', 'sex', 'age', 'EDUCATION', 'Unnamed: 0'])

eeg_df2['GROUP'].unique()
# Out:
# array(['CTL', 'ALC_early_state', 'ALC_chronic_state'], dtype=object)

# %%
'''
    Create new target features where 
        0 means controlled, not addicted
        1 means addicted, early stage
        2 means addicted for long period, chronic stage
'''

eeg_df2['GROUP'] = np.where(eeg_df2['GROUP'] == 'CTL', 0, eeg_df2['GROUP'])
eeg_df2['GROUP'] = np.where(eeg_df2['GROUP'] == 'ALC_early_state', 1, eeg_df2['GROUP'])
eeg_df2['GROUP'] = np.where(eeg_df2['GROUP'] == 'ALC_chronic_state', 2, eeg_df2['GROUP'])

# %% [markdown]
# ### Remove features with low deviation and EDA with correlation

# %%
eeg_df_low_deviation = eeg_df2.columns[abs(eeg_df2.std()) < 0.01]
eeg_df_low_deviation
# Out:
# Index(['pz', 'cp2', 'cz', 'afz', 'poz', 'po4', 'p2', 'cp4', 'c2'], dtype='object')

# %%
eeg_df3 = eeg_df2.drop(columns=eeg_df_low_deviation)
eeg_df3 = eeg_df2

# %%
eeg_df3[eeg_df3['GROUP'] == 0].head()
# Out:
#    GROUP  BDI  AUDIT       fp1        fz        f3        f7  below_eye  \
# 0      0   14      1 -0.006885  0.001531 -0.002528 -0.013197  -0.013694
# 1      0    2      2  0.006728  0.013835  0.015602  0.006617  -0.002029
# 2      0    2      1 -0.026259 -0.000343 -0.000536 -0.006117  -0.016435
# 3      0    8      3 -0.005962  0.014713  0.005335  0.022881   0.012168
# 16     0    2      1 -0.023188 -0.006138 -0.024324 -0.030981  -0.004326
#
#          fc5       fc1  ...        c2       fc4       ft8        f6        f2  \
# 0  -0.009282  0.004364  ... -0.006757 -0.000072 -0.013844 -0.011792 -0.009998
# 1   0.013220  0.008777  ... -0.009466 -0.003701  0.011509  0.003604  0.009692
# 2  -0.020814 -0.001995  ... -0.001402 -0.009827 -0.016021 -0.013534  0.005141
# 3   0.008540  0.000893  ...  0.013867 -0.003909  0.000481 -0.009388 -0.007416
# 16 -0.016813 -0.013119  ...  0.002857 -0.015837  0.002011 -0.014997  0.001220
#
#          af4       af8     empty       ekg  audiooutput
# 0  -0.012524 -0.025626  0.012368  1.830811     0.002748
# 1  -0.008439  0.004798  2.803576  0.004948     0.002710
# 2   0.000050 -0.023162  0.012644  1.379198     0.002720
# 3   0.000051 -0.006602  0.012423 -0.186586     0.002769
# 16 -0.020649 -0.022581  0.012412 -1.572366     0.002800
#
# [5 rows x 69 columns]

# %%
eeg_df3[eeg_df3['GROUP'] == 1].head()
# Out:
#    GROUP  BDI  AUDIT       fp1        fz        f3        f7  below_eye  \
# 4      1    5      7 -0.010039 -0.001393 -0.003494 -0.005115  -0.010285
# 6      1    1     11 -0.018977 -0.012562 -0.003156 -0.029378  -0.005898
# 7      1   17      9 -0.003868 -0.002087  0.012339 -0.006504  -0.029840
# 9      1    1      7  0.005726  0.001772 -0.001047 -0.013619   0.004430
# 10     1    0      7 -0.007604  0.021150  0.026183 -0.010864  -0.001817
#
#          fc5       fc1  ...        c2       fc4       ft8        f6        f2  \
# 4   0.004411 -0.001367  ...  0.009685  0.008228  0.011959  0.005457  0.002437
# 6  -0.010873 -0.000858  ...  0.004662 -0.019951 -0.036140 -0.025300 -0.012703
# 7   0.004096 -0.002428  ... -0.002402 -0.006424 -0.008929 -0.000462 -0.003708
# 9  -0.008633  0.001295  ... -0.004151  0.001691  0.008780 -0.019290 -0.005178
# 10  0.006965  0.014757  ...  0.015193 -0.003509 -0.010686  0.021952  0.011366
#
#          af4       af8     empty       ekg  audiooutput
# 4   0.007888  0.001032  0.012321  0.379675     1.040810
# 6  -0.025295 -0.022501  0.012303  0.050009     0.002838
# 7  -0.001394 -0.005028  0.012398  0.233600     0.002816
# 9  -0.000259 -0.010479  0.012151  1.786867     0.002802
# 10  0.017762  0.005693  0.012167  0.158007     0.002780
#
# [5 rows x 69 columns]

# %% [markdown]
# ### Select features with correlation with target higher than threshold

# %%
corr_threshold = 0.11

eeg_df_corr = eeg_df3.corr()
corr_add_level = eeg_df_corr['GROUP']
corr_add_level = eeg_df_corr.columns[abs(corr_add_level) > corr_threshold]
corr_add_level
# Out:
# Index(['GROUP', 'BDI', 'AUDIT', 'f7', 'c3', 'cp5', 'p3', 'o1', 'o2', 'p4',
#        'fc6', 'c1', 'cp3', 'p1', 'po7', 'po3', 'po8', 'p6', 'cp4', 'af8',
#        'empty'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize correlation map
# Not visualize here, takes much of time, hard to see

# plt.figure(figsize=(len(eeg_df_corr.columns), len(eeg_df_corr.columns)))
# cor = eeg_df_corr.corr()
# sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
# plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize correlation map after select features

plt.figure(figsize=(len(corr_add_level), len(corr_add_level)))
cor = eeg_df3[corr_add_level].corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# eeg_df4 = eeg_df3[corr_add_level]
# eeg_df4['GROUP'] = eeg_df3['GROUP']
eeg_df4 = eeg_df3[corr_add_level].drop(columns=['BDI', 'AUDIT'])
# eeg_df4 = eeg_df3.drop(columns=['BDI', 'AUDIT'])

# %%
# eeg_df_target = eeg_df4['GROUP']
eeg_df_target = eeg_df4['GROUP']
eeg_df_features = eeg_df4.drop(columns=['GROUP'])
# eeg_df_features = eeg_df4.drop(columns=['GROUP', 'BDI', 'AUDIT'])

# %%
eeg_df4.head()
# Out:
#   GROUP        f7        c3       cp5        p3        o1        o2        p4  \
# 0     0 -0.013197 -0.010254 -0.411213 -0.011409  0.005106  0.001102 -0.009405
# 1     0  0.006617  0.017131  0.016273  0.009761  0.006606  0.005211  0.005093
# 2     0 -0.006117  0.000428 -0.003443  0.001448  0.005817  0.004257  0.001420
# 3     0  0.022881  0.004453  0.014815  0.004490 -0.000656  0.006123 -0.008475
# 4     1 -0.005115  0.006417 -0.004600  0.022134  0.008174  0.007164  0.008922
#
#         fc6        c1       cp3        p1       po7       po3       po8  \
# 0 -0.007126 -0.003675  0.001428 -0.012521 -0.010903  0.002152  0.001368
# 1  0.014645  0.002709  0.019105  0.010611  0.010341  0.006912  0.004391
# 2 -0.010481  0.002632  0.004531  0.003209  0.002198 -0.006929 -0.014278
# 3 -0.006042  0.003046  0.005840 -0.005583  0.012220 -0.010885  0.005047
# 4  0.001496  0.010708 -0.000591  0.020415  0.004583  0.005552  0.010533
#
#          p6       cp4       af8     empty
# 0 -0.003709 -0.010550 -0.025626  0.012368
# 1  0.004018  0.010947  0.004798  2.803576
# 2 -0.011327 -0.004955 -0.023162  0.012644
# 3  0.001160  0.008836 -0.006602  0.012423
# 4  0.004592  0.002306  0.001032  0.012321

# %% [markdown]
# ### Drop features with absolute correlation with each other features more than threshold

# %%
def correlation(data, threshold):
    col_corr = set()
    corr_matrix = data.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(eeg_df_features, 0.6)
# corr_features = correlation(eeg_df4, 0.7)
len(set(corr_features))
# Out:
# 9

# %%
corr_features
# Out:
# {'c1', 'c3', 'cp4', 'p1', 'p4', 'p6', 'po3', 'po7', 'po8'}

# %%
eeg_df_features_2 = eeg_df_features.drop(corr_features, axis=1)
# eeg_df_features_2 = eeg_df_features
# eeg_df_features_2 = eeg_df4.drop(corr_features, axis=1)
eeg_df_features_2.columns
# Out:
# Index(['f7', 'cp5', 'p3', 'o1', 'o2', 'fc6', 'cp3', 'af8', 'empty'], dtype='object')

# %%
eeg_df_features_2.head()
# Out:
#          f7       cp5        p3        o1        o2       fc6       cp3  \
# 0 -0.013197 -0.411213 -0.011409  0.005106  0.001102 -0.007126  0.001428
# 1  0.006617  0.016273  0.009761  0.006606  0.005211  0.014645  0.019105
# 2 -0.006117 -0.003443  0.001448  0.005817  0.004257 -0.010481  0.004531
# 3  0.022881  0.014815  0.004490 -0.000656  0.006123 -0.006042  0.005840
# 4 -0.005115 -0.004600  0.022134  0.008174  0.007164  0.001496 -0.000591
#
#         af8     empty
# 0 -0.025626  0.012368
# 1  0.004798  2.803576
# 2 -0.023162  0.012644
# 3 -0.006602  0.012423
# 4  0.001032  0.012321

# %%
# Visualize correlation map after dropping highly correlated features


plt.figure(figsize=(len(eeg_df_features_2.columns), len(eeg_df_features_2.columns)))
cor = eeg_df_features_2.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %% [markdown]
# ### Try with multiple data solutions:
# - Only Remove unnecessary columns (Pure data)
# - Standardized Data
# - Using PCA without any transformation
# - Using PCA with data transform

# %%
sub_directory = "processed_data"
if not os.path.exists(sub_directory):
    os.makedirs(sub_directory)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
eeg_standardized = pd.DataFrame(sc.fit_transform(eeg_df_features_2), columns=eeg_df_features_2.columns)

# %%
eeg_standardized['GROUP'] = eeg_df_target

# %%
eeg_standardized['GROUP'].unique()
# Out:
# array([0, 1, 2], dtype=object)

# %%
eeg_standardized.to_csv(f'{sub_directory}\\Standardized_data.csv', index=False)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.9)
pca_df = pd.DataFrame(sc.fit_transform(eeg_df_features_2), columns=eeg_df_features_2.columns)
pca_df['GROUP'] = eeg_df_target
pca_df.to_csv(f'{sub_directory}\\Transformed_pca.csv')

# %%
pure_data = eeg_df2.drop(columns=['GROUP', 'BDI', 'AUDIT'])
pure_data['GROUP'] = eeg_df_target
pure_data.to_csv(f'{sub_directory}\\Pure_data.csv', index=False)
pure_data.columns
# Out:
# Index(['fp1', 'fz', 'f3', 'f7', 'below_eye', 'fc5', 'fc1', 'c3', 't7',
#        'left_mastoid', 'cp5', 'cp1', 'pz', 'p3', 'p7', 'o1', 'oz', 'o2', 'p4',
#        'p8', 'right_mastoid', 'cp6', 'cp2', 'cz', 'c4', 't8', 'above_eye',
#        'fc6', 'fc2', 'f4', 'f8', 'fp2', 'af7', 'af3', 'afz', 'f1', 'f5', 'ft7',
#        'fc3', 'fcz', 'c1', 'c5', 'tp7', 'cp3', 'p1', 'p5', 'po7', 'po3', 'poz',
#        'po4', 'po8', 'p6', 'p2', 'cp4', 'tp8', 'c6', 'c2', 'fc4', 'ft8', 'f6',
#        'f2', 'af4', 'af8', 'empty', 'ekg', 'audiooutput', 'GROUP'],
#       dtype='object')

# %%
pca2 = PCA(n_components=34)

pure_pca = pure_data.drop(columns=['GROUP'])
pure_pca = pd.DataFrame(sc.fit_transform(pure_pca), columns=pure_pca.columns)
pure_pca = pca2.fit_transform(pure_data)

# %%
pure_pca_df = pd.DataFrame(pure_pca, columns=[f'PC{i+1}' for i in range(pure_pca.shape[1])])
pure_pca_df['GROUP'] = eeg_df_target
# Save to CSV
pure_pca_df.to_csv(f'{sub_directory}\\no_transform_pca.csv', index=False)
